# %%
import pandas as pd

data = pd.read_excel('sz50.xlsx', sheetname=None, index_col='datetime')
print(data.keys())
# Out:
# odict_keys(['600000.XSHG', '600016.XSHG', '600028.XSHG', '600029.XSHG', '600030.XSHG', '600036.XSHG', '600048.XSHG', '600050.XSHG', '600100.XSHG', '600104.XSHG', '600111.XSHG', '600340.XSHG', '600485.XSHG', '600518.XSHG', '600519.XSHG', '600547.XSHG', '600606.XSHG', '600837.XSHG', '600887.XSHG', '600919.XSHG', '600958.XSHG', '600999.XSHG', '601006.XSHG', '601088.XSHG', '601166.XSHG', '601169.XSHG', '601186.XSHG', '601198.XSHG', '601211.XSHG', '601229.XSHG', '601288.XSHG', '601318.XSHG', '601328.XSHG', '601336.XSHG', '601390.XSHG', '601398.XSHG', '601601.XSHG', '601628.XSHG', '601668.XSHG', '601688.XSHG', '601766.XSHG', '601788.XSHG', '601800.XSHG', '601818.XSHG', '601857.XSHG', '601881.XSHG', '601901.XSHG', '601985.XSHG', '601988.XSHG', '601989.XSHG'])

# %%
import datetime
import numpy as np
import talib as ta

data2=pd.read_excel('sz50.xlsx', sheetname='600036.XSHG', index_col='datetime')
series=data2.close
array=np.array(series)
print(type(array))
print(ta.MA(array,10)[-5:])
# Out:
# <class 'numpy.ndarray'>
# [ 108.35   108.741  109.176  110.102  111.666]

# %%
s=pd.Series(ta.MA(array,10))
print(s)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9       69.701
# 10      69.890
# 11      70.122
# 12      70.284
# 13      70.515
# 14      70.731
# 15      71.086
# 16      71.445
# 17      71.831
# 18      72.024
# 19      72.040
# 20      72.090
# 21      72.094
# 22      72.183
# 23      72.311
# 24      72.496
# 25      72.496
# 26      72.592
# 27      72.642
# 28      72.762
# 29      73.078
#         ...
# 185    102.859
# 186    102.919
# 187    103.043
# 188    103.143
# 189    103.566
# 190    104.093
# 191    104.776
# 192    105.534
# 193    106.021
# 194    106.188
# 195    106.387
# 196    106.690
# 197    106.761
# 198    107.519
# 199    107.886
# 200    107.914
# 201    107.830
# 202    107.794
# 203    107.910
# 204    107.954
# 205    108.118
# 206    108.234
# 207    108.442
# 208    108.031
# 209    107.983
# 210    108.350
# 211    108.741
# 212    109.176
# ...

# %%
import matplotlib.pyplot as plt
stock1=data2
new_index = pd.date_range("20170103",periods=len(s), freq="1.5D")
s.index = new_index#??
stock2=s

plt.figure(figsize=(15, 7))
plt.plot(stock1.close)#plot线图
plt.plot(stock2)
plt.ylabel('Price')
plt.legend(['600036','601318'])#即图中左上角的小标签
plt.show()
